# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'D:\Devi\ICT_TVM\Bootcamp\auto-mpg.csv')
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
data.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin         car name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
data.shape
# Out:
# (398, 9)

# %%
data.shape[0]
# Out:
# 398

# %%
data.shape[1]
# Out:
# 9

# %%
cols=data.columns
cols
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
 data.index  #rows
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
data.sort_values( by='mpg')
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 28    9.0          8         304.0        193    4732          18.5
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 103  11.0          8         400.0        150    4997          14.0
# 124  11.0          8         350.0        180    3664          11.0
# ..    ...        ...           ...        ...     ...           ...
# 326  43.4          4          90.0         48    2335          23.7
# 394  44.0          4          97.0         52    2130          24.6
# 325  44.3          4          90.0         48    2085          21.7
# 329  44.6          4          91.0         67    1850          13.8
# 322  46.6          4          86.0         65    2110          17.9
#
#      model year  origin              car name
# 28           70       1              hi 1200d
# 25           70       1             ford f250
# ...

# %%
data.sort_values(by = 'mpg',ascending= False) #Descending order
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 322  46.6          4          86.0         65    2110          17.9
# 329  44.6          4          91.0         67    1850          13.8
# 325  44.3          4          90.0         48    2085          21.7
# 394  44.0          4          97.0         52    2130          24.6
# 326  43.4          4          90.0         48    2335          23.7
# ..    ...        ...           ...        ...     ...           ...
# 103  11.0          8         400.0        150    4997          14.0
# 67   11.0          8         429.0        208    4633          11.0
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 28    9.0          8         304.0        193    4732          18.5
#
#      model year  origin              car name
# 322          80       3             mazda glc
# 329          80       3   honda civic 1500 gl
# ...

# %%
data.sort_values(by = ['cylinders','mpg'])
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 111  18.0          3          70.0         90    2124          13.5
# 71   19.0          3          70.0         97    2330          13.5
# 243  21.5          3          80.0        110    2720          13.5
# 334  23.7          3          70.0        100    2420          12.5
# 76   18.0          4         121.0        112    2933          14.5
# ..    ...        ...           ...        ...     ...           ...
# 165  20.0          8         262.0        110    3221          13.5
# 251  20.2          8         302.0        139    3570          12.8
# 298  23.0          8         350.0        125    3900          17.4
# 300  23.9          8         260.0         90    3420          22.2
# 364  26.6          8         350.0        105    3725          19.0
#
#      model year  origin                           car name
# 111          73       3                          maxda rx3
# ...

# %%
data.sort_values(by = ['cylinders','mpg'],ascending = [True,False]) # one ascending and another descending
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 334  23.7          3          70.0        100    2420          12.5
# 243  21.5          3          80.0        110    2720          13.5
# 71   19.0          3          70.0         97    2330          13.5
# 111  18.0          3          70.0         90    2124          13.5
# 322  46.6          4          86.0         65    2110          17.9
# ..    ...        ...           ...        ...     ...           ...
# 103  11.0          8         400.0        150    4997          14.0
# 124  11.0          8         350.0        180    3664          11.0
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 28    9.0          8         304.0        193    4732          18.5
#
#      model year  origin          car name
# 334          80       3     mazda rx-7 gs
# 243          77       3        mazda rx-4
# ...

# %%
data[['mpg','horsepower']]
# Out:
#       mpg horsepower
# 0    18.0        130
# 1    15.0        165
# 2    18.0        150
# 3    16.0        150
# 4    17.0        140
# ..    ...        ...
# 393  27.0         86
# 394  44.0         52
# 395  32.0         84
# 396  28.0         79
# 397  31.0         82
#
# [398 rows x 2 columns]

# %%
data['mpg']>30
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394     True
# 395     True
# 396    False
# 397     True
# Name: mpg, Length: 398, dtype: bool

# %% [markdown]
# ## Boolean indexing

# %%
mask1=data['mpg']>30
data[mask1]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 53   31.0          4          71.0         65    1773          19.0
# 54   35.0          4          72.0         69    1613          18.0
# 129  31.0          4          79.0         67    1950          19.0
# 131  32.0          4          71.0         65    1836          21.0
# 144  31.0          4          76.0         52    1649          16.5
# ..    ...        ...           ...        ...     ...           ...
# 390  32.0          4         144.0         96    2665          13.9
# 391  36.0          4         135.0         84    2370          13.0
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin             car name
# 53           71       3  toyota corolla 1200
# 54           71       3          datsun 1200
# ...

# %%
data[data['mpg']>30]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 53   31.0          4          71.0         65    1773          19.0
# 54   35.0          4          72.0         69    1613          18.0
# 129  31.0          4          79.0         67    1950          19.0
# 131  32.0          4          71.0         65    1836          21.0
# 144  31.0          4          76.0         52    1649          16.5
# ..    ...        ...           ...        ...     ...           ...
# 390  32.0          4         144.0         96    2665          13.9
# 391  36.0          4         135.0         84    2370          13.0
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin             car name
# 53           71       3  toyota corolla 1200
# 54           71       3          datsun 1200
# ...

# %%
data[data['displacement']>150]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 386  25.0          6         181.0        110    2945          16.4
# 387  38.0          6         262.0         85    3015          17.0
# 388  26.0          4         156.0         92    2585          14.5
# 389  22.0          6         232.0        112    2835          14.7
# 392  27.0          4         151.0         90    2950          17.3
#
#      model year  origin                           car name
# 0            70       1          chevrolet chevelle malibu
# ...

# %%
data[data['cylinders']==3]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 71   19.0          3          70.0         97    2330          13.5
# 111  18.0          3          70.0         90    2124          13.5
# 243  21.5          3          80.0        110    2720          13.5
# 334  23.7          3          70.0        100    2420          12.5
#
#      model year  origin         car name
# 71           72       3  mazda rx2 coupe
# 111          73       3        maxda rx3
# 243          77       3       mazda rx-4
# 334          80       3    mazda rx-7 gs

# %%
mask1=data['cylinders']==3
mask2=data['cylinders']==4

# %%
data[(mask1)|(mask2)]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 14   24.0          4         113.0         95    2372          15.0
# 18   27.0          4          97.0         88    2130          14.5
# 19   26.0          4          97.0         46    1835          20.5
# 20   25.0          4         110.0         87    2672          17.5
# 21   24.0          4         107.0         90    2430          14.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                      car name
# 14           70       3         toyota corona mark ii
# ...

# %%
mask3=data['cylinders'].isin([3,4])

# %%
data[mask3]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 14   24.0          4         113.0         95    2372          15.0
# 18   27.0          4          97.0         88    2130          14.5
# 19   26.0          4          97.0         46    1835          20.5
# 20   25.0          4         110.0         87    2672          17.5
# 21   24.0          4         107.0         90    2430          14.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                      car name
# 14           70       3         toyota corona mark ii
# ...

# %%
data['Weight_in_ton']=data['weight']/1000 # create an extra column--feature engineering

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name  Weight in tons  \
# 0            70       1  chevrolet chevelle malibu           3.504
# ...

# %%
data['Weight/displacement']=data['weight']/data['displacement']

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name  Weight in tons  \
# 0            70       1  chevrolet chevelle malibu           3.504
# ...

# %%
a = np.array([[-7,5,-2,4],[5,2,7,3],[10,-13,-3,5]])
a
# Out:
# array([[ -7,   5,  -2,   4],
#        [  5,   2,   7,   3],
#        [ 10, -13,  -3,   5]])

# %%
data.min()
# Out:
# mpg                                        9.0
# cylinders                                    3
# displacement                              68.0
# horsepower                                 100
# weight                                    1613
# acceleration                               8.0
# model year                                  70
# origin                                       1
# car name               amc ambassador brougham
# Weight in tons                           1.613
# Weight_in_ton                            1.613
# Weight/displacement                   6.782418
# dtype: object

# %%
data['mpg'].min()
# Out:
# 9.0

# %%
data['mpg'].max()
# Out:
# 46.6

# %%
data['mpg'].mean()
# Out:
# 23.514572864321615

# %%
data['mpg'].std()
# Out:
# 7.815984312565782

# %%
data['mpg'].var()
# Out:
# 61.089610774274405

# %%
data.describe(include='object')
# Out:
#        horsepower    car name
# count         398         398
# unique         94         305
# top           150  ford pinto
# freq           22           6

# %%
data['mpg'].quantile(.25)
# Out:
# 17.5

# %%
data['mpg'].quantile(.75)
# Out:
# 29.0

# %%
data['mpg'].quantile([0.25,0.75,0.995])
# Out:
# 0.250    17.5000
# 0.750    29.0000
# 0.995    44.3045
# Name: mpg, dtype: float64

# %%
data['cylinders'].value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
data['cylinders'].nunique()
# Out:
# 5

# %%
data['cylinders'].unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
data.loc[ :, ] # all the  columns and rows
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name  Weight in tons  \
# 0            70       1  chevrolet chevelle malibu           3.504
# ...

# %%
data.loc[ :,'mpg' ]
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
data.loc[ 2:,'mpg' ]
# Out:
# 2      18.0
# 3      16.0
# 4      17.0
# 5      15.0
# 6      14.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 396, dtype: float64

# %%
data.loc[ 2:10,'mpg' ]
# Out:
# 2     18.0
# 3     16.0
# 4     17.0
# 5     15.0
# 6     14.0
# 7     14.0
# 8     14.0
# 9     15.0
# 10    15.0
# Name: mpg, dtype: float64

# %%
data.loc[ 2:10,'mpg':'origin' ]
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 2   18.0          8         318.0        150    3436          11.0
# 3   16.0          8         304.0        150    3433          12.0
# 4   17.0          8         302.0        140    3449          10.5
# 5   15.0          8         429.0        198    4341          10.0
# 6   14.0          8         454.0        220    4354           9.0
# 7   14.0          8         440.0        215    4312           8.5
# 8   14.0          8         455.0        225    4425          10.0
# 9   15.0          8         390.0        190    3850           8.5
# 10  15.0          8         383.0        170    3563          10.0
#
#     model year  origin
# 2           70       1
# 3           70       1
# 4           70       1
# 5           70       1
# 6           70       1
# 7           70       1
# 8           70       1
# 9           70       1
# 10          70       1

# %%
data.loc[2:10,['mpg','weight','origin']]
# Out:
#      mpg  weight  origin
# 2   18.0    3436       1
# 3   16.0    3433       1
# 4   17.0    3449       1
# 5   15.0    4341       1
# 6   14.0    4354       1
# 7   14.0    4312       1
# 8   14.0    4425       1
# 9   15.0    3850       1
# 10  15.0    3563       1

# %%
data.loc[[300,305,39],['mpg','weight','origin']]
# Out:
#       mpg  weight  origin
# 300  23.9    3420       1
# 305  28.4    2670       1
# 39   14.0    4464       1

# %%
data.iloc[[300,305,39,],[0,4,7]] #taking corresponding index values
# Out:
#       mpg  weight  origin
# 300  23.9    3420       1
# 305  28.4    2670       1
# 39   14.0    4464       1

# %%
data.iloc[10:50,2:5]
# Out:
#     displacement horsepower  weight
# 10         383.0        170    3563
# 11         340.0        160    3609
# 12         400.0        150    3761
# 13         455.0        225    3086
# 14         113.0         95    2372
# 15         198.0         95    2833
# 16         199.0         97    2774
# 17         200.0         85    2587
# 18          97.0         88    2130
# 19          97.0         46    1835
# 20         110.0         87    2672
# 21         107.0         90    2430
# 22         104.0         95    2375
# 23         121.0        113    2234
# 24         199.0         90    2648
# 25         360.0        215    4615
# 26         307.0        200    4376
# 27         318.0        210    4382
# 28         304.0        193    4732
# 29          97.0         88    2130
# 30         140.0         90    2264
# 31         113.0         95    2228
# 32          98.0          ?    2046
# 33         232.0        100    2634
# 34         225.0        105    3439
# ...

# %%
# droping duplicate rows

# %%
data.drop_duplicates()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name  Weight in tons  \
# 0            70       1  chevrolet chevelle malibu           3.504
# ...

# %%
data.drop_duplicates(subset='mpg')
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# 6    14.0          8         454.0        220    4354           9.0
# ..    ...        ...           ...        ...     ...           ...
# 362  24.2          6         146.0        120    2930          13.8
# 363  22.4          6         231.0        110    3415          15.8
# 369  34.0          4         112.0         88    2395          18.0
# 378  38.0          4         105.0         63    2125          14.7
# 394  44.0          4          97.0         52    2130          24.6
#
#      model year  origin                   car name  Weight in tons  \
# 0            70       1  chevrolet chevelle malibu           3.504
# ...

# %%
data.drop_duplicates(subset=['mpg','cylinders'])
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# 6    14.0          8         454.0        220    4354           9.0
# ..    ...        ...           ...        ...     ...           ...
# 369  34.0          4         112.0         88    2395          18.0
# 378  38.0          4         105.0         63    2125          14.7
# 386  25.0          6         181.0        110    2945          16.4
# 387  38.0          6         262.0         85    3015          17.0
# 394  44.0          4          97.0         52    2130          24.6
#
#      model year  origin                           car name  Weight in tons  \
# ...

# %%
data.sample(100) # randomly select 100 rows of data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 90   12.0          8         429.0        198    4952          11.5
# 205  28.0          4          97.0         75    2155          16.4
# 200  18.0          6         250.0         78    3574          21.0
# 184  25.0          4         140.0         92    2572          14.9
# 285  17.0          8         305.0        130    3840          15.4
# ..    ...        ...           ...        ...     ...           ...
# 125  20.0          6         198.0         95    3102          16.5
# 43   13.0          8         400.0        170    4746          12.0
# 91   13.0          8         400.0        150    4464          12.0
# 73   13.0          8         307.0        130    4098          14.0
# 113  21.0          6         155.0        107    2472          14.0
#
#      model year  origin                          car name  Weight in tons  \
# 90           73       1          mercury marquis brougham           4.952
# ...

# %%
data.sample(frac=.25) # randomly select 25% of data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 214  13.0          8         302.0        130    3870          15.0
# 330  40.9          4          85.0          ?    1835          17.3
# 296  27.4          4         121.0         80    2670          15.0
# 380  36.0          4         120.0         88    2160          14.5
# 21   24.0          4         107.0         90    2430          14.5
# ..    ...        ...           ...        ...     ...           ...
# 397  31.0          4         119.0         82    2720          19.4
# 324  40.8          4          85.0         65    2110          19.2
# 147  24.0          4          90.0         75    2108          15.5
# 178  23.0          4         120.0         88    2957          17.0
# 375  36.0          4         105.0         74    1980          15.3
#
#      model year  origin              car name  Weight in tons  Weight_in_ton  \
# ...

# %%
data.sample(frac=.25,random_state=15) # randomly select 25% of data,random state set the data doesnt change
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 353  33.0          4         105.0         74    2190          14.2
# 21   24.0          4         107.0         90    2430          14.5
# 216  31.5          4          98.0         68    2045          18.5
# 67   11.0          8         429.0        208    4633          11.0
# 131  32.0          4          71.0         65    1836          21.0
# ..    ...        ...           ...        ...     ...           ...
# 9    15.0          8         390.0        190    3850           8.5
# 80   22.0          4         122.0         86    2395          16.0
# 38   14.0          8         350.0        165    4209          12.0
# 106  12.0          8         350.0        180    4499          12.5
# 372  27.0          4         151.0         90    2735          18.0
#
#      model year  origin                  car name  Weight in tons  \
# 353          81       2          volkswagen jetta           2.190
# ...

# %%
data.sample(frac=.25,random_state=15,replace=True) # randomly with replacement
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 245  36.1          4          98.0         66    1800          14.4
# 396  28.0          4         120.0         79    2625          18.6
# 133  16.0          6         250.0        100    3781          17.0
# 375  36.0          4         105.0         74    1980          15.3
# 384  32.0          4          91.0         67    1965          15.7
# ..    ...        ...           ...        ...     ...           ...
# 82   23.0          4         120.0         97    2506          14.5
# 231  15.5          8         400.0        190    4325          12.2
# 90   12.0          8         429.0        198    4952          11.5
# 180  25.0          4         121.0        115    2671          13.5
# 370  31.0          4         112.0         85    2575          16.2
#
#      model year  origin                           car name  Weight in tons  \
# ...

# %%
data['cylinders'].value_counts()/len(data) ## proportions
# Out:
# 4    0.512563
# 8    0.258794
# 6    0.211055
# 3    0.010050
# 5    0.007538
# Name: cylinders, dtype: float64

# %%
(data['cylinders'].value_counts()/len(data))*100
# Out:
# 4    51.256281
# 8    25.879397
# 6    21.105528
# 3     1.005025
# 5     0.753769
# Name: cylinders, dtype: float64

# %%
data['cylinders'].value_counts()/data.shape[0]*100
# Out:
# 4    51.256281
# 8    25.879397
# 6    21.105528
# 3     1.005025
# 5     0.753769
# Name: cylinders, dtype: float64

# %%
data['cylinders'].value_counts(normalize=True)*100
# Out:
# 4    51.256281
# 8    25.879397
# 6    21.105528
# 3     1.005025
# 5     0.753769
# Name: cylinders, dtype: float64

# %%
data.groupby(by='cylinders')['mpg'].mean()
# Out:
# cylinders
# 3    20.550000
# 4    29.286765
# 5    27.366667
# 6    19.985714
# 8    14.963107
# Name: mpg, dtype: float64

# %%
data.groupby(by='origin')['mpg'].mean()
# Out:
# origin
# 1    20.083534
# 2    27.891429
# 3    30.450633
# Name: mpg, dtype: float64

# %%
data.groupby(by=['origin','cylinders'])['mpg'].mean()
# Out:
# origin  cylinders
# 1       4            27.840278
#         6            19.663514
#         8            14.963107
# 2       4            28.411111
#         5            27.366667
#         6            20.100000
# 3       3            20.550000
#         4            31.595652
#         6            23.883333
# Name: mpg, dtype: float64

# %%
data.groupby(by=['origin','cylinders'])['mpg','weight'].mean()
# Out:
# C:\Users\Akhil\AppData\Local\Temp\ipykernel_18888\48807043.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(by=['origin','cylinders'])['mpg','weight'].mean()
#                         mpg       weight
# origin cylinders
# 1      4          27.840278  2437.166667
#        6          19.663514  3213.905405
#        8          14.963107  4114.718447
# 2      4          28.411111  2330.015873
#        5          27.366667  3103.333333
#        6          20.100000  3382.500000
# 3      3          20.550000  2398.500000
#        4          31.595652  2153.492754
#        6          23.883333  2882.000000

# %%
data.groupby(by=['origin','cylinders'])['mpg','weight'].min()
# Out:
#                    mpg  weight
# origin cylinders
# 1      4          19.0    1800
#        6          15.0    2472
#        8           9.0    3086
# 2      4          18.0    1825
#        5          20.3    2830
#        6          16.2    3140
# 3      3          18.0    2124
#        4          20.0    1613
#        6          19.0    2807

# %%
data.groupby(by=['origin','cylinders'])['mpg','weight'].agg([min,max,sum])
# Out:
#                    mpg               weight
#                    min   max     sum    min   max     sum
# origin cylinders
# 1      4          19.0  39.0  2004.5   1800  3035  175476
#        6          15.0  38.0  1455.1   2472  3907  237829
#        8           9.0  26.6  1541.2   3086  5140  423816
# 2      4          18.0  44.3  1789.9   1825  3270  146791
#        5          20.3  36.4    82.1   2830  3530    9310
#        6          16.2  30.7    80.4   3140  3820   13530
# 3      3          18.0  23.7    82.2   2124  2720    9594
#        4          20.0  46.6  2180.1   1613  2711  148591
#        6          19.0  32.7   143.3   2807  2930   17292

# %%
pd.DataFrame
dict1 = {'Name':['Anju', 'Ajithra', 'jayaram', 'Georgia'],
        'Maths':[87, 91, 97, 95],
        'Science':[83, 99, 84, 76]
       }

# %%
dict1
# Out:
# {'Name': ['Anju', 'Ajithra', 'jayaram', 'Georgia'],
#  'Maths': [87, 91, 97, 95],
#  'Science': [83, 99, 84, 76]}

# %%
DF=pd.DataFrame(dict1)
DF
# Out:
#       Name  Maths  Science
# 0     Anju     87       83
# 1  Ajithra     91       99
# 2  jayaram     97       84
# 3  Georgia     95       76

# %%
DF.loc[4] = ['Sahitha', 89, 93]

# %%
DF
# Out:
#       Name  Maths  Science
# 0     Anju     87       83
# 1  Ajithra     91       99
# 2  jayaram     97       84
# 3  Georgia     95       76
# 4  Sahitha     89       93

# %%
DF.loc[5] = ['Mridula', 90, 93]

# %%
DF
# Out:
#       Name  Maths  Science
# 0     Anju     87       83
# 1  Ajithra     91       99
# 2  jayaram     97       84
# 3  Georgia     95       76
# 4  Sahitha     89       93
# 5  Mridula     90       93

# %%
DF['Total'] = DF['Maths']+DF['Science']

# %%
DF
# Out:
#       Name  Maths  Science  Total
# 0     Anju     87       83    170
# 1  Ajithra     91       99    190
# 2  jayaram     97       84    181
# 3  Georgia     95       76    171
# 4  Sahitha     89       93    182
# 5  Mridula     90       93    183

# %%
DF[DF['Maths']>90]
# Out:
#       Name  Maths  Science  Total
# 1  Ajithra     91       99    190
# 2  jayaram     97       84    181
# 3  Georgia     95       76    171

# %%
n=int(input("Enter the limit 1:"))
m=int(input("Enter the limit 2:"))
print ("The Prime Numbers between: ", n, "and", m, "are:") 
for number in range(n,m+1):
    if(number>1):
        for i in range(2,number):
            if((number%i) ==0):
                break
        else:
            print(number)
# Out:
# Enter the limit 1: 5
# Enter the limit 2: 20
# The Prime Numbers between:  5 and 20 are:
# 5
# 7
# 11
# 13
# 17
# 19
